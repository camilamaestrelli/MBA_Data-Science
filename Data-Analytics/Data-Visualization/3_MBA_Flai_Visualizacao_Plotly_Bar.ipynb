# %% [markdown]
# ![Logo_MBA_Flai.png](data:image/png;base64,...)

# %% [markdown]
# # **BNDES - Operações financeiras não automáticas**

# %% [markdown]
# ## **Entendendo o contexto**

# %% [markdown]
# ### **Quem é o BNDES**
#
# De acordo com a página [**"Quem somos"**](https://www.bndes.gov.br/wps/portal/site/home/quem-somos) do site do BNDES:
#
# Fundado em 1952, o **Banco Nacional de Desenvolvimento Econômico e Social (BNDES) é um dos maiores bancos de desenvolvimento do mundo** e, hoje, o **principal instrumento do Governo Federal para o financiamento** de longo prazo **e investimento em todos os segmentos da economia brasileira**.
#
# Para isso, **apoia empreendedores de todos os portes**, **inclusive pessoas físicas**, na realização de seus planos de modernização, de expansão e na concretização de novos negócios, tendo sempre em vista o potencial de geração de empregos, renda e de inclusão social para o Brasil.
#
# O apoio do BNDES ocorre **por meio de financiamento a investimentos**, subscrição de valores mobiliários, prestação de garantia e concessão de recursos não reembolsáveis a projetos de caráter social, cultural e tecnológico. O Banco atua por meio de produtos, programas e fundos, conforme a modalidade e a característica das operações.
#
# **Por ser uma empresa pública e não um banco comercial**, o **BNDES avalia a concessão do apoio com foco no impacto socioambiental e econômico no Brasil.** **Incentivar a inovação, o desenvolvimento regional e o desenvolvimento socioambiental são prioridades para a instituição.**
#
# O BNDES **oferece condições especiais para micro, pequenas e médias empresas**, aquelas que faturam anualmente até R$ 300 milhões, assim como **linhas de investimentos sociais, direcionadas para educação e saúde, agricultura familiar, saneamento básico e transporte urbano**.
#
# Em situações de crise, o Banco também tem fundamental atuação anticíclica e auxilia na formulação das soluções para a retomada do crescimento da economia. O ***BNDES está presente para apoiar o crescimento do País onde é necessário***.

# %%
from IPython.core.display import HTML
HTML('<iframe width="1000" height="500" src="https://www.youtube.com/embed/teMf3B05g78" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="1000" height="500" src="https://www.youtube.com/embed/teMf3B05g78" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ### **O Objetivo da Aula**

# %% [markdown]
# Entender os financiamentos do BNDES através de visualizações de dados

# %% [markdown]
# ### **O Dataset**
#
# No portal de dados abertos do BNDES, encontra-se disponível uma área com disponibilidade para download de dois arquivos de microdados de operações financeiras: operações indiretas automáticas e operações não automáticas. Neste segundo arquivo contém tanto as operações diretas (contratadas diretamente com o BNDES) quanto as indiretas (contratadas através de agentes financeiros). As não automáticas são as que 2 necessitam de análise de um Analista do BNDES, e geralmente são as operações de valores maiores.
#
# Nesses conjuntos de dados cada instância é uma operação financeira de financiamento e contém atributos da:
#
# - **empresa:** nome da empresa, CNPJ, municípios e UF onde estão localizados a
# empresa, natureza da empresa se é pública ou privada, se for pública se é da esfera federal, estadual ou municipal, porte da empresa (se pequena, média ou grande), Qual setor de atividade econômica da empresa (CNAE com setor e subsetor);
# - **forma de negociação:** se direta ou indireta, se indireta qual foi o agente financeiro, qual foi o tipo de garantia da operação;
# - **sobre a contratação:** qual tipo de produto BNDES foi contratado, qual instrumento financeiro utilizado, se era para um projeto de inovação, qual área operacional do BNDES tratou desta operação financeira;
# - **sobre o financiamento:** Valor contratado, taxa de juros, custo financeiro, prazo de carência, prazo para amortização, modalidade de apoio; situação do financiamento na data da última atualização do dataset (se liquidado ou ativo).
#
#
#
# Link para download do arquivo csv contendo os microdados:
# - https://dadosabertos.bndes.gov.br/dataset/operacoes-financiamento/resource/332d446e-d340-46ef-af64-ee6f36e7bd50

# %% [markdown]
# ### **A Biblioteca Plotly**

# %% [markdown]
# Plotly é uma biblioteca que fornece diversos gráficos dinâmicos e interativos.
#
# Para maiores informações do Plotly, consulte a documentação no endereço a seguir:
#
# - https://plotly.com/

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **Hands-on**
#
# 1. **Carregar dados**;
# 2. **Entender a estrutura dos dados**;
# 3. **Transformar dados**;
# 4. **Elaboração do Treemap**.

# %% [markdown]
# ### **Carregando o conjunto de dados**

# %%
# Fazendo download do conjunto de dados
# !wget --verbose --show-progress --no-check-certificate https://raw.githubusercontent.com/jonates/opendata/master/bndes/operacoes-financiamento-operacoes-nao-automaticas.csv
# Out:
# --2022-04-28 15:06:08--  https://raw.githubusercontent.com/jonates/opendata/master/bndes/operacoes-financiamento-operacoes-nao-automaticas.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 15990084 (15M) [text/plain]
# Saving to: ‘operacoes-financiamento-operacoes-nao-automaticas.csv.2’
#
# operacoes-financiam 100%[===================>]  15.25M  --.-KB/s    in 0.1s
#
# 2022-04-28 15:06:09 (146 MB/s) - ‘operacoes-financiamento-operacoes-nao-automaticas.csv.2’ saved [15990084/15990084]

# %%
# Importando o Pandas
import pandas as pd

# %%
# Importando o conjunto de dados da Netflix
bndes = pd.read_csv(
    filepath_or_buffer = '/content/operacoes-financiamento-operacoes-nao-automaticas.csv', 
    sep=';',
    decimal=',',
    encoding = 'utf-8'
)

# %%
# Espiando o conjunto de dados
bndes
# Out:
#                                                  cliente                cnpj  \
# 0                            MUNICIPIO DE RIBEIRAO PRETO  56.024.581/0001-56
# 1      INSTITUTO DE DESENVOLVIMENTO SUSTENTAVEL DO BA...  02.275.306/0001-86
# 2      INSTITUTO DE DESENVOLVIMENTO SUSTENTAVEL DO BA...  02.275.306/0001-86
# 3      INSTITUTO DE DESENVOLVIMENTO SUSTENTAVEL DO BA...  02.275.306/0001-86
# 4                                               ACEF S/A  46.722.831/0001-78
# ...                                                  ...                 ...
# 19658                                        DPR TELECOM  00.422.413/0001-64
# 19659                              RIVELLI ALIMENTOS S/A  21.005.582/0001-79
# 19660                           SCHULZ COMPRESSORES LTDA  23.635.798/0001-43
# 19661                            TRAMONTINA ELETRIK S.A.  88.674.080/0001-01
# 19662        CAEMMUN INDUSTRIA E COMERCIO DE MOVEIS LTDA  81.904.948/0001-73
#
# ...

# %% [markdown]
# ### **Espiando a estrutura dos dados**

# %%
# Informacoes gerais do conjunto de dados
bndes.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19663 entries, 0 to 19662
# Data columns (total 34 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   cliente                                     19663 non-null  object
#  1   cnpj                                        19663 non-null  object
#  2   descricao_do_projeto                        19663 non-null  object
#  3   uf                                          19663 non-null  object
#  4   municipio                                   19663 non-null  object
#  5   municipio_codigo                            19663 non-null  int64
#  6   numero_do_contrato                          19663 non-null  int64
#  7   data_da_contratacao                         19663 non-null  object
#  8   valor_contratado_reais                      19663 non-null  float64
# ...

# %%
# Verificando valores missing
bndes.isnull().sum()
# Out:
# cliente                                       0
# cnpj                                          0
# descricao_do_projeto                          0
# uf                                            0
# municipio                                     0
# municipio_codigo                              0
# numero_do_contrato                            0
# data_da_contratacao                           0
# valor_contratado_reais                        0
# valor_desembolsado_reais                      0
# fonte_de_recurso_desembolsos                  0
# custo_financeiro                              0
# juros                                         0
# prazo_carencia_meses                          0
# prazo_amortizacao_meses                       0
# modalidade_de_apoio                           0
# forma_de_apoio                                0
# produto                                       0
# instrumento_financeiro                        0
# inovacao                                      0
# ...

# %% [markdown]
# ### **Transformações no Conjunto de dados**

# %%
# Transformação data_da_contratacao em formato de data
bndes['data'] = pd.to_datetime(bndes.data_da_contratacao, infer_datetime_format=True)

# %%
# Extraindo o Ano da variável data
bndes['ano'] = pd.DatetimeIndex(bndes['data']).year

# %%
# Verificando a nova estrutura do dataset
bndes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19663 entries, 0 to 19662
# Data columns (total 36 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   cliente                                     19663 non-null  object
#  1   cnpj                                        19663 non-null  object
#  2   descricao_do_projeto                        19663 non-null  object
#  3   uf                                          19663 non-null  object
#  4   municipio                                   19663 non-null  object
#  5   municipio_codigo                            19663 non-null  int64
#  6   numero_do_contrato                          19663 non-null  int64
#  7   data_da_contratacao                         19663 non-null  object
#  8   valor_contratado_reais                      19663 non-null  float64
# ...

# %%
# Dando mais uma espiada no conjunto de dados
bndes.head(2)
# Out:
#                                              cliente                cnpj  \
# 0                        MUNICIPIO DE RIBEIRAO PRETO  56.024.581/0001-56
# 1  INSTITUTO DE DESENVOLVIMENTO SUSTENTAVEL DO BA...  02.275.306/0001-86
#
#                                 descricao_do_projeto  uf       municipio  \
# 0  PROGRAMA DE MODERNIZACAO DA ADMINISTRACAO TRIB...  SP  RIBEIRAO PRETO
# 1  PROJETO DIREITO E CIDADANIA; PROJETO DEMONSTRA...  BA         ITUBERA
#
#    municipio_codigo  numero_do_contrato data_da_contratacao  \
# 0           3543402             1247021          2002-01-02
# 1           2917300             1247221          2002-01-03
#
#    valor_contratado_reais  valor_desembolsado_reais  ...       subsetor_bndes  \
# 0              9090000.00                 9007445.1  ...  COMÉRCIO E SERVIÇOS
# 1                75691.59                   78500.0  ...  COMÉRCIO E SERVIÇOS
#
#   porte_do_cliente                               natureza_do_cliente  \
# ...

# %%
# Filtrando somente os financiamentos que ocorreram à partir de 2018
bndes_2018 = bndes.query('ano==2018')

# %%
# Espiando o conjunto de dados
bndes_2018.ano.value_counts()
# Out:
# 2018    635
# Name: ano, dtype: int64

# %% [markdown]
# ### **Gerando visualizações**

# %%
# Importando as bibliotecas necessarias
import plotly.express as px

# %% [markdown]
# #### **Quantidade de financiamentos por setor do BNDES**

# %%
# Contando as operações por setor
df_bndes_setor = bndes_2018[['setor_bndes']]\
                      .value_counts()\
                      .to_frame()\
                      .reset_index()\
                      .rename(columns={0: 'financiamentos'})

# Espiando o resultado
df_bndes_setor
# Out:
#          setor_bndes  financiamentos
# 0     INFRAESTRUTURA             284
# 1          INDUSTRIA             173
# 2  COMERCIO/SERVICOS             149
# 3       AGROPECUÁRIA              29

# %%
 # Construindo o Gráfico de colunas
px.bar(
  data_frame = df_bndes_setor, 
  x = 'setor_bndes',
  y = 'financiamentos' 
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **Quantidade de financiamentos por setor do BNDES e Inovação**

# %%
# Contando as operações por setor e inovacao
df_setor_inovacao = bndes_2018[['setor_bndes','inovacao']]\
                      .value_counts()\
                      .to_frame()\
                      .reset_index()\
                      .rename(columns={0: 'financiamentos'})

# Espiando o df resultante
df_setor_inovacao
# Out:
#          setor_bndes inovacao  financiamentos
# 0     INFRAESTRUTURA      NÃO             282
# 1          INDUSTRIA      NÃO             154
# 2  COMERCIO/SERVICOS      NÃO             135
# 3       AGROPECUÁRIA      NÃO              29
# 4          INDUSTRIA      SIM              19
# 5  COMERCIO/SERVICOS      SIM              14
# 6     INFRAESTRUTURA      SIM               2

# %%
# Grafico barras da quantidade de financiamentos por setor e inovacao
px.bar(
    data_frame = df_setor_inovacao, 
    x="setor_bndes", 
    y="financiamentos", 
    color="inovacao"
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Grafico barras da quantidade de financiamentos por setor e inovacao
px.bar(
    data_frame = df_setor_inovacao, 
    x="setor_bndes", 
    y="financiamentos", 
    color="inovacao", 
    barmode='group',
    text_auto=True
)

# importante!: o barmode do grafico anterior era barmode='relative'
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Grafico barras da quantidade de financiamentos por setor e inovacao
px.bar(
    data_frame = df_setor_inovacao, 
    x="setor_bndes", 
    y="financiamentos", 
    color="inovacao", 
    barmode='overlay'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Grafico barras da quantidade de financiamentos por setor e inovacao
px.histogram(
    data_frame = df_setor_inovacao, 
    x="setor_bndes", 
    y="financiamentos", 
    color="inovacao", 
    barmode='relative',
    barnorm = 'percent',
    color_discrete_map = { 
      'NÃO' : 'lightblue' , 
      'SIM' : 'purple'
    },
    title = 'Percentual do Financiamentos do BNDES para Inovação, em 2018, por Setor.'
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### **Valor desembolsado nos financiamentos por setor do BNDES e Inovação**

# %%
# Gerando df valor desembolsado por UF
df_bndes_uf_valor = bndes_2018[['uf','valor_desembolsado_reais']] \
                      .groupby('uf', as_index = False ) \
                      .sum()

# Espiando o df resultante
df_bndes_uf_valor
# Out:
#     uf  valor_desembolsado_reais
# 0   AC              4.548125e+06
# 1   AM              4.074482e+07
# 2   AP              0.000000e+00
# 3   BA              2.467739e+09
# 4   CE              2.993122e+07
# 5   DF              2.000000e+07
# 6   ES              1.333830e+08
# 7   GO              1.713183e+08
# 8   IE              1.100878e+10
# 9   MA              6.564230e+08
# 10  MG              1.993312e+09
# 11  MS              2.811965e+08
# 12  MT              1.959881e+09
# 13  PA              1.278201e+09
# 14  PB              1.000000e+07
# 15  PE              9.414949e+08
# 16  PR              1.877216e+09
# 17  RJ              2.242376e+09
# 18  RN              9.462090e+08
# 19  RO              2.351296e+07
# 20  RS              2.832500e+09
# 21  SC              1.062363e+09
# 22  SE              7.717000e+04
# 23  SP              6.819851e+09
# 24  TO              3.949636e+05

# %%
 # Construindo o Gráfico de barras
px.bar(
  data_frame = df_bndes_uf_valor, 
  y = 'uf',
  x = 'valor_desembolsado_reais',
  orientation = 'h' 
)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
 # Construindo o Gráfico de barras com ajustes
grafico_barras_valor_uf = px.bar(
  data_frame = df_bndes_uf_valor, 
  y = 'uf',
  x = 'valor_desembolsado_reais',
  orientation = 'h',
  title = 'Total desembolsado em reais nos financiamentos do BNDES, em 2018, por UF.',
  height=800, 
  width=700,
  labels = {
      'uf' : 'Unidade da Federação',
      'valor_desembolsado_reais' : 'Valor desembolsado em reais'
  }
)

# Organizando em ordem decrescente
grafico_barras_valor_uf.update_layout(yaxis={'categoryorder':'total ascending'})

# Alterando as cores do gráfico
grafico_barras_valor_uf.update_traces(
    marker_color='green', 
    marker_line_color='black',
    marker_line_width=0.5, 
    opacity=0.9
)

# Exibindo o Gráfico
grafico_barras_valor_uf.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Para mais detalhes veja a documentação do plotly nos seguintes links:
# - https://plotly.com/python-api-reference/generated/plotly.express.bar
# - https://plotly.com/python/bar-charts/
# - https://plotly.com/python/styling-plotly-express/
# - https://plotly.com/python/plotly-express/
# - https://plotly.com/python/px-arguments/
# - https://plotly.com/python/wide-form/
# - https://plotly.com/python-api-reference/generated/plotly.express.histogram

# %% [markdown]
# ### **Faça Você mesmo**

# %% [markdown]
# Contrua gráficos de barras para entender a relação entre o fato do turnover ocorrer após 1 ano de empresa ou antes de um ano de empresa, com características dos funcionários da empresa. O conjunto de dados pode acessado em: https://raw.githubusercontent.com/jonates/opendata/master/turnover/turnover_treino.csv
